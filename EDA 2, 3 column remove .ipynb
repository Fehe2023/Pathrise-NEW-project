# %% [markdown]
# <a href="https://colab.research.google.com/github/Fehe2023/Pathrise-NEW-project/blob/main/EDA%202%2C%203%20column%20remove%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-9079001a-0b22-46c0-8d00-4b6f78fb7455" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9079001a-0b22-46c0-8d00-4b6f78fb7455">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('Data_Pathrise.csv')

# %%
df.describe(include="all")
# Out:
#                  id pathrise_status primary_track cohort_tag  \
# count   2544.000000            2544          2544       2536
# unique          NaN               9             6         47
# top             NaN          Placed           SWE     JAN19A
# freq            NaN             956          1678        132
# mean    1272.500000             NaN           NaN        NaN
# std      734.533866             NaN           NaN        NaN
# min        1.000000             NaN           NaN        NaN
# 25%      636.750000             NaN           NaN        NaN
# 50%     1272.500000             NaN           NaN        NaN
# 75%     1908.250000             NaN           NaN        NaN
# max     2544.000000             NaN           NaN        NaN
#
#         program_duration_days       placed employment_status   \
# count             1928.000000  2544.000000               2315
# unique                    NaN          NaN                  5
# ...

# %%
df= df.drop (['id','primary_track','cohort_tag'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2544 entries, 0 to 2543
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   pathrise_status              2544 non-null   object
#  1   program_duration_days        1928 non-null   float64
#  2   placed                       2544 non-null   int64
#  3   employment_status            2315 non-null   object
#  4   highest_level_of_education   2486 non-null   object
#  5   length_of_job_search         2470 non-null   object
#  6   biggest_challenge_in_search  2520 non-null   object
#  7   professional_experience      2322 non-null   object
#  8   work_authorization_status    2260 non-null   object
#  9   number_of_interviews         2326 non-null   float64
#  10  number_of_applications       2544 non-null   int64
#  11  gender                       2052 non-null   object
#  12  race                         2526 non-null   object
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/My Drive")
# !ls
# Out:
# 'Colab Notebooks'		  week14-applied-datascience.mp4    week6-applied-datascience.mp4
#  df				  week15-applied-datascience.mp4    week6-applied-datascience.pdf
#  df.csv				  week1-applied-datascience.mp4     week7-applied-datascience.mp4
# 'my drive 2'			  week2-applied-datascience.mp4     week7-applied-datascience.pdf
#  week10-applied-datascience.mp4   week3-applied-datascience.mp4     week8-applied-datascience.mp4
#  week11-applied-datascience.mp4   week4-applied-datascience.mp4     week9-applied-datascience.mp4
#  week12-applied-datascience.mp4   week5-applied-datascience.mp4
#  week13-applied-datascience.mp4   week6-applied-datascience-1.pdf

# %%
df.to_csv('/content/drive/My Drive/df/patchrise 2.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2544 entries, 0 to 2543
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   pathrise_status              2544 non-null   object
#  1   program_duration_days        1928 non-null   float64
#  2   placed                       2544 non-null   int64
#  3   employment_status            2315 non-null   object
#  4   highest_level_of_education   2486 non-null   object
#  5   length_of_job_search         2470 non-null   object
#  6   biggest_challenge_in_search  2520 non-null   object
#  7   professional_experience      2322 non-null   object
#  8   work_authorization_status    2260 non-null   object
#  9   number_of_interviews         2326 non-null   float64
#  10  number_of_applications       2544 non-null   int64
#  11  gender                       2052 non-null   object
#  12  race                         2526 non-null   object
# ...
